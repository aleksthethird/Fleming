# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')

# %%
lc1 = np.loadtxt('l140id760.txt')
lc2 = np.loadtxt('l141_5id302.txt')
lc3 = np.loadtxt('l196id507.txt')
lc4 = np.loadtxt('l197id98.txt')
lc5 = np.loadtxt('l198id1594.txt')
lc6 = np.loadtxt('l198id2269.txt')
lc7 = np.loadtxt('l198_5id686.txt')
lc8 = np.loadtxt('l199id147.txt')

# %%
lc1_time = lc1[:,0] / 3600.0
lc1_flux = lc1[:,1] / np.average(lc1[:,1])
lc2_time = lc2[:,0] / 3600.0
lc2_flux = lc2[:,1] / np.average(lc2[:,1])
lc3_time = lc3[:,0] / 3600.0
lc3_flux = lc3[:,1] / np.average(lc3[:,1])
lc4_time = lc4[:,0] / 3600.0
lc4_flux = lc4[:,1] / np.average(lc4[:,1])
lc5_time = lc5[:,0] / 3600.0
lc5_flux = lc5[:,1] / np.average(lc5[:,1])
lc6_time = lc6[:,0] / 3600.0
lc6_flux = lc6[:,1] / np.average(lc6[:,1])
lc7_time = lc7[:,0] / 3600.0
lc7_flux = lc7[:,1] / np.average(lc7[:,1])
lc8_time = lc8[:,0] / 3600.0
lc8_flux = lc8[:,1] / np.average(lc8[:,1])

# %%
# %matplotlib inline
plt.rc('font', family='serif')
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
fig = plt.figure(figsize=(10, 8))

# %%
plt.ylabel('Relative flux',fontsize=15)
plt.xlabel('Time (hours)',fontsize=15)
plt.yticks([0.8,1.0,1.2])
plt.ylim(np.min(lc1_flux)*0.98,np.max(lc1_flux)*1.02)
plt.xlim(0.0,np.max(lc1_time))
plt.scatter(lc1_time,lc1_flux)
plt.text(0.1,1.33,r'#1: $\alpha\,47.3294$ $\delta\,58.3436$ $G=14.782$',fontsize=15)
# Out:
# Text(0.1, 1.33, '#1: $\\alpha\\,47.3294$ $\\delta\\,58.3436$ $G=14.782$')

# %%
plt.ylabel('Relative flux',fontsize=15)
plt.xlabel('Time (hours)',fontsize=15)
plt.yticks([0.8,1.0,1.2])
plt.ylim(np.min(lc2_flux)*0.98,np.max(lc2_flux)*1.06)
plt.xlim(0.0,np.max(lc2_time))
plt.scatter(lc2_time,lc2_flux)
plt.text(0.1,1.3,r'#2: $\alpha\,48.9935$ $\delta\,57.4448$ $G=14.597$',fontsize=15)
# Out:
# Text(0.1, 1.3, '#2: $\\alpha\\,48.9935$ $\\delta\\,57.4448$ $G=14.597$')

# %%
plt.ylabel('Relative flux',fontsize=15)
plt.xlabel('Time (hours)',fontsize=15)
plt.yticks([0.6,0.8,1.0,1.2,1.4])
plt.ylim(np.min(lc3_flux)*0.98,np.max(lc3_flux)*1.08)
plt.xlim(0.0,np.max(lc3_time))
plt.scatter(lc3_time,lc3_flux)
plt.text(0.1,1.35,r'#3: $\alpha\,95.2913$ $\delta\,14.8230$ $G=14.999$',fontsize=15)
# Out:
# Text(0.1, 1.35, '#3: $\\alpha\\,95.2913$ $\\delta\\,14.8230$ $G=14.999$')

# %%
plt.ylabel('Relative flux',fontsize=15)
plt.xlabel('Time (hours)',fontsize=15)
plt.yticks([0.8,1.0,1.2,1.4])
plt.ylim(np.min(lc4_flux)*0.98,np.max(lc4_flux)*1.07)
plt.xlim(0.0,np.max(lc4_time))
plt.scatter(lc4_time,lc4_flux)
plt.text(0.1,1.4,r'#4: $\alpha\,95.5928$ $\delta\,13.9018$ $G=14.082$',fontsize=15)
# Out:
# Text(0.1, 1.4, '#4: $\\alpha\\,95.5928$ $\\delta\\,13.9018$ $G=14.082$')

# %%
plt.ylabel('Relative flux',fontsize=15)
plt.xlabel('Time (hours)',fontsize=15)
plt.yticks([0.9,1.0,1.1])
plt.ylim(np.min(lc5_flux)*0.98,np.max(lc5_flux)*1.04)
plt.xlim(0.0,np.max(lc5_time))
plt.scatter(lc5_time,lc5_flux)
plt.text(0.1,1.18,r'#5: $\alpha\,96.1482$ $\delta\,13.2645$ $G=12.559$',fontsize=15)
# Out:
# Text(0.1, 1.18, '#5: $\\alpha\\,96.1482$ $\\delta\\,13.2645$ $G=12.559$')

# %%
plt.ylabel('Relative flux',fontsize=15)
plt.xlabel('Time (hours)',fontsize=15)
plt.ylim(np.min(lc6_flux)*0.98,np.max(lc6_flux)*1.1)
plt.xlim(0.0,np.max(lc6_time))
plt.scatter(lc6_time,lc6_flux)
plt.text(0.1,2.25,r'#6: $\alpha\,95.9051$ $\delta\,13.4145$ $G=16.460$',fontsize=15)
# Out:
# Text(0.1, 2.25, '#6: $\\alpha\\,95.9051$ $\\delta\\,13.4145$ $G=16.460$')

# %%
plt.ylabel('Relative flux',fontsize=15)
plt.xlabel('Time (hours)',fontsize=15)
plt.ylim(np.min(lc7_flux)*0.98,np.max(lc7_flux)*1.06)
plt.xlim(0.0,np.max(lc7_time))
plt.scatter(lc7_time,lc7_flux)
plt.text(0.1,1.18,r'#7: $\alpha\,96.0834$ $\delta\,12.7554$ $G=14.812$',fontsize=15)
# Out:
# Text(0.1, 1.18, '#7: $\\alpha\\,96.0834$ $\\delta\\,12.7554$ $G=14.812$')

# %%
plt.ylabel('Relative flux',fontsize=15)
plt.xlabel('Time (hours)',fontsize=15)
plt.ylim(np.min(lc8_flux)*0.97,np.max(lc8_flux)*1.02)
plt.yticks([0.9,1.0,1.1])
plt.xlim(0.0,np.max(lc8_time))
plt.scatter(lc8_time,lc8_flux)
plt.text(0.1,1.13,r'#8: $\alpha\,96.3854$ $\delta\,12.1703$ $G=12.786$',fontsize=15)
# Out:
# Text(0.1, 1.13, '#8: $\\alpha\\,96.3854$ $\\delta\\,12.1703$ $G=12.786$')
